# %% [markdown]
# This dataset is a cleaned version of the Rotten Tomatoes movie information merged with review counts and freshness scores, as prepared in our data analysis script.
#
# The EDA will include summary statistics, data quality checks, distribution analysis, and visualizations to uncover patterns and insights.

# %%
# Importing libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os

# %%
# Create visuals folder if it doesn't exist
os.makedirs('../visuals/EDA/rotten_tomatoes', exist_ok=True)

# Load the cleaned dataset
rt_combined_df_cleaned = pd.read_csv('../data/cleaned/rt_combined_df_cleaned.csv')

# %%
# 1. Data Overview
print("=== 1. Data Overview ===")
print("\n1.1. Data Info:")
print(rt_combined_df_cleaned.info())
print("\n1.2. First 5 Rows:")
print(rt_combined_df_cleaned.head())
print("\n1.3. Column Names:")
print(rt_combined_df_cleaned.columns.tolist())
print("\n1.4. Missing Values:")
print(rt_combined_df_cleaned.isnull().sum())
print("\n1.5. Data Shape:", rt_combined_df_cleaned.shape)
print("\n" + "="*50 + "\n")
# Out:
# === 1. Data Overview ===
#
# 1.1. Data Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1316 entries, 0 to 1315
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               1316 non-null   int64
#  1   synopsis         1316 non-null   object
#  2   rating           1316 non-null   object
#  3   genre            1316 non-null   object
#  4   director         1316 non-null   object
#  5   writer           1316 non-null   object
#  6   runtime          1316 non-null   float64
#  7   studio           1316 non-null   object
#  8   Review_counts    1316 non-null   float64
#  9   Freshness_score  1316 non-null   float64
# dtypes: float64(3), int64(1), object(6)
# memory usage: 102.9+ KB
# None
#
# 1.2. First 5 Rows:
#    id                                           synopsis rating  \
# 0   1  This gritty, fast-paced, and innovative police...      R
# 1   5  Illeana Douglas delivers a superb performance ...      R
# 2   6  Michael Douglas runs afoul of a treacherous su...      R
# 3   8  The year is 1942. As the Allies unite overseas...     PG
# 4  10  Some cast and crew from NBC's highly acclaimed...  PG-13
#
#                                  genre          director  \
# 0  Action and Adventure|Classics|Drama  William Friedkin
# 1    Drama|Musical and Performing Arts    Allison Anders
# 2           Drama|Mystery and Suspense    Barry Levinson
# 3                Drama|Kids and Family       Jay Russell
# 4                               Comedy       Jake Kasdan
#
#                             writer  runtime                 studio  \
# 0                   Ernest Tidyman    104.0                Unknown
# 1                   Allison Anders    116.0                Unknown
# 2  Paul Attanasio|Michael Crichton    128.0                Unknown
# 3                  Gail Gilchriest     95.0  Warner Bros. Pictures
# 4                       Mike White     82.0     Paramount Pictures
#
#    Review_counts  Freshness_score
# 0            0.0         0.635514
# 1           23.0         0.782609
# 2           57.0         0.561404
# 3           75.0         0.746667
# 4          108.0         0.462963
#
# 1.3. Column Names:
# ['id', 'synopsis', 'rating', 'genre', 'director', 'writer', 'runtime', 'studio', 'Review_counts', 'Freshness_score']
#
# 1.4. Missing Values:
# id                 0
# synopsis           0
# rating             0
# genre              0
# director           0
# writer             0
# runtime            0
# studio             0
# Review_counts      0
# Freshness_score    0
# dtype: int64
#
# 1.5. Data Shape: (1316, 10)
#
# ==================================================
